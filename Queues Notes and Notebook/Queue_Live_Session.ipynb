# %% [markdown]
# |                                     |                                      |
# | ---                                 | ---                                  |
# | <img src="http://drive.google.com/uc?export=view&id=1JzM1Jig5KAOCvU4tIf2t66B3gd1uy1rG" width=200px> |<img src="http://drive.google.com/uc?export=view&id=1kMibD1EUis_6bwFtFIOgvUg22zEdROns" width=200px>|
#
# Proprietary content. © Great Learning. All Rights Reserved. Unauthorized use or distribution prohibited.

# %% [markdown]
# # <font color='blue'> Table Of Contents </font>
#
# ## <font color='blue'> Queues </font>
#
# ## <font color='blue'> Implementation of Queue
#
# * Using Arrays
# * Using Linked lists
# * Using Stacks </font>
#
# ## <font color='blue'> Priority Queues </font>
#
# ## <font color='blue'> Implementation of Queues </font>
#
# ## <font color='blue'> Source Code </font>
#
# * Linked List Implementation
# * Stack Implementation

# %% [markdown]
# # <font color='blue'> Queues </font>
#
# A queue is an ordered collection of items where the insertion of new items happens at one end. This end is generally known as <rear>. The deletion of any existing items can happen at only one end, this is generally called the front.
#
# Once the item inserted inside the queue, it starts at the rear and makes its way toward the front, waiting until that time when it is the next item to be removed from the queue.
#
# In queue, the most recently inserted item in the queue should be available at the end of the collection.
#
# The item that has been in the collection the longest should be available at the front. This ordering principle is also called as FIFO, first-in first-out.
#
# ## <font color='blue'> Queue: Abstract Data Types </font>
#
# The queue operations are given below.
#
# * Queue() creates a new queue that is empty. It needs no parameters and returns an empty queue.
#
# * enqueue(item) adds a new item to the rear of the queue. It needs the item and returns nothing.
#
# * dequeue() removes the front item from the queue. It needs no parameters and returns the item. The queue is modified.
#
# * is_empty() tests to see whether the queue is empty. It needs no parameters and returns a boolean value.
#
# * size() returns the number of items in the queue. It needs no parameters and returns an integer.
#
#
# # <font color='blue'> Implementation of Queue </font>
#
# Queue data structure can be implemented using Arrays, Linked lists and stacks as well. Lets have a look at the implementation of Linked lists and Stack implementation of Queue in detail.
#
# ## <font color='blue'> Implementation Using Array </font>
#
#
# ![Queue-using-Array.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ## <font color='blue'> Implementation Using Linked List </font>
#
# Lets explore the implementation of queue using linked list. Before we will see the code lets have a look at the properties and some generic variables that need to be there.
#
# As we know that every linked list will have its own head and tail pointers to point the beginning and the end of the linked list respectively.
#
# However for the implementation of queue as per the member and property of queue, we can rename these variables as front and rear. All the operations such as insert, delete, front and rear will happen using these two variables only.
#
# ![Queue_linked_list.jpg](data:image/jpeg;base64,...)
#
#
# In this section, we are going to use properties of singly linked list to implement Queue data structure, where every node will contain at least two information;
#
#     * Node value
#     * Reference to the next pointer
#
#
# Lets have a look at the <class Node> and the members of it.

# %%
class Node:
    def __init__(self, data):
        self.data = data
        self.next = None

# %% [markdown]
# Here we have declared a class that has two variables data and next.
#
# - <data> variable will be used to hold the values assigned by the user
# - <next> will be used to hold the address/momory reference to the next node.
#
# Once we have established a way to create the node for our stack implementation, we need to implement methods to perform ADT operations on the stack.
#
# Also declaring a structire for node is not sufficient, for every push operation we need to maintain the next pointer for new data and for every pop opeartion also appropriate node values i.e. next pointer/reference should be updated.
#
# Lets have a look at the attached code and explanation associated with it.

# %%
# This is a Linked list implementation of Stack data structure in genric way. 
# This code conatins basic ADT of stack
    # * Enqueue
    # * Dequeue
    # * GetFront
    # * GetRear
    # * Show
    
class Queue:
    def __init__(self):
        self.front = None
        self.rear = None

# %% [markdown]
# ### <font color='blue'>  Enqueue Operation </font>

# %%
    # This method will insert data in the queue. 
        def enqueue(self, data):
            tmp = Node(data)
            if self.rear is None:
                self.front = self.rear = tmp
                return
            else:
                self.rear.next = self.rear = tmp

# %% [markdown]
# ### <font color='blue'> isempty Operation </font>

# %%
    # Checking if Stack is empty
    def isempty(self):
        # 1. If front is None
            #a. Queue is empty 
        if self.front is None:
            return True
        #2. Queue has some element. 
        else:
            return False

# %% [markdown]
# ### <font color='blue'>  getrear & getfront Operation </font>

# %%
    def getrear(self):
        # 1. Checking if Queue is empty
        if self.isempty():
            print("Queue is empty")
        else:
            # printing the rear element of the queue.
            print("Rear element of Queue is :", end =" ")
            print(self.rear.data)
            
    def getfront(self):
        # 1. Checking if Queue is empty
        if self.isempty():
            print("Queue is empty")
        else:
            # printing the front element of the queue.
            print("Front element of Queue is :", end =" ")
            print(self.front.data)

# %% [markdown]
# ### <font color='blue'> Dequeue Operation </font>

# %%
    # Method to delete the elements one by one form the queue    
    def deque(self):
        #1. Check if queue is empty
        if self.isempty():
            print("Queue is empty")
            self.front = None
            self.rear = None
        #2. If the queue has some element then deletion can happen
        # we need to update the front as well 
        else:
            #a. save the front reference in another variable
            #b. Move the front pointer to the next node
            #c. Print the data
            #d. delete the node data
            tmp = self.front
            print("Deleted element is element of Queue is :", end =" ")
            print(tmp.data)
            self.front = tmp.next
            del tmp
            if self.isempty():
                self.rear = None

# %% [markdown]
# ## <font color='blue'> Implementation Using Stacks </font>
#
# Lets explore the implementation of queue using stack data structure.
#
# To implement this we will be using array/lists implementation of stack data structure. Lets have a look at the pseudo code.
#
# #### Algorithm
#
#     Declare Stack1, Stack2.
#
#     Enqueue:
#
#         Push data into stack1.
#
#     Dequeue:
#
#         While (!isempty(Stack1))
#            value = Pop from stack1
#            Push value into stack2
#
#         returnval = Pop from Stack2
#
#         return returnval

# %% [markdown]
# Lets have a look at some of the operation and how it is basic queue operations are taking place.
#
#
# ![Queue_using_stack_enqueue.JPG](data:image/jpeg;base64,...)
#
# ![Queue_using_stack_dequeue.JPG](data:image/jpeg;base64,...)

# %% [markdown]
# ### <font color='blue'> Stack Class </font>

# %%
class Stack:

    def __init__(self):
        self.items = []

    def push(self, item):
        self.items.append(item)

    def pop(self):
        return self.items.pop()

    def size(self):
        return len(self.items)

    def is_empty(self):
        return self.items == []

# %%
class Queue(object):

    def __init__(self):

        # Initializing two Stacks
        self.stack1 = Stack()
        self.stack2 = Stack()

    def enqueue(self, item):
        self.stack1.push(item)

    def dequeue(self):
        
        if self.stack1.size() == 0 and self.stack2.size() == 0:
            print("Queue is Empty")
            return
 
        # if s2 is empty and s1 has elements
        elif self.stack2.size() == 0 and self.stack1.size() > 0:
            while self.stack1.size():
                temp = self.stack1.pop()
                self.stack2.push(temp)
            return self.stack2.pop()
 
        else:
            return self.stack2.pop()
# Out:
# 1
# 2
# 3
# 5
# 6

# %%
# Driver code
if __name__ == '__main__':
    q = Queue()
    q.enqueue(1)
    q.enqueue(2)
    q.enqueue(3)
    a = q.dequeue()
    print(a)
    b = q.dequeue()
    print(b)
    q.enqueue(5)
    c = q.dequeue()
    print(c)
    q.enqueue(6)
    print(q.dequeue())
    print(q.dequeue())
    
    """
    Order of enqueue operation in queue is 1, 2, 3, 5, 6
    Deletion of elements from queue should happen in following order: 1, 2, 3, 5, 6
    """
    
    """
    # Testing code for large input
    for i in range(5):
        print(i)
        q.enqueue(i)
    for i in range(5):
        print(q.dequeue())
    """

# %% [markdown]
# # <font color='blue'> Priority Queue </font>
#
# In this section, we will be understanding one of the most broadly useful sophisticated data structures, the priority queue.
#
# A priority queue is designed for applications in which elements have a priority value, or key, and each time we need to select an element from S, we want to take the one with highest priority.
#
# A priority queue is a data structure that maintains a set of elements S, where each element v ∈ S has an associated value key(v) that denotes the priority of element v; smaller keys represent higher priorities. Priority queues support the addition and deletion of elements from the set, and also the selection of the element with smallest key
#
# Priority queues are useful in multiple situations such as priority based task scheduler, graph algorithms etc.
#
# For our purposes here, it is a useful illustration of the analysis of a data structure that, unlike lists and arrays, must perform some nontrivial processing each time it is invoked.
#
#
# ## <font color='blue'> Implementation of Priority Queue </font>

# %%
class Node:
    def __init__(self, data, priority):
        self.data = data
        self.priority = priority
        self.next = None

class Queue:
    
    def __init__(self):
        self.front = None
        self.rear = None

    # This method will insert data in the queue. 
    def enqueue(self, val, prior):
        # Creating the node for insertion
        tmp = Node(val, prior)
        # Checking if the Queue is empty
        if self.rear is None:
            self.front = self.rear = tmp
            return
        
        # if queue has only one element 
        # Inserting the element and rearraning the front
        if (self.front.priority > prior):
            tmp.next = self.front
            self.front = tmp
            
        # Finding the right position to insert the elelemnt in the queue
        # this will ensure the priority of elelemnts are arranged.  
        else:
            p = self.front
            while p.next != None and p.next.priority <prior:
                p = p.next
            
            tmp.next = p.next
            p.next = tmp

    def isempty(self):
        # 1. If front is None
        #a. Queue is empty 
        if self.front is None:
            return True
        #2. Queue has some element. 
        else:
            return False


    def dequeue(self):
        #1. Check if queue is empty
        if self.isempty():
            print("Queue is empty")
            self.front = None
            self.rear = None
        #2. If the queue has some element then deletion can happen
        # we need to update the front as well 
        else:
            #a. save the front reference in another variable
            #b. Move the front pointer to the next node
            #c. Print the data
            #d. delete the node data
            tmp = self.front
            print("Deleted element is element of Queue is :", end =" ")
            print(tmp.data)
            self.front = tmp.next
            del tmp
            if self.isempty():
                self.rear = None

q = Queue()

q.enqueue("P1", 10)
q.enqueue("P2", 12)
q.enqueue("P3", 1)
q.enqueue("P4", 2)

q.dequeue()
q.dequeue()
q.dequeue()
q.dequeue()
q.dequeue()
# Out:
# Deleted element is element of Queue is : P3
# Deleted element is element of Queue is : P4
# Deleted element is element of Queue is : P1
# Deleted element is element of Queue is : P2
# Queue is empty

# %% [markdown]
# # <font color='blue'> Source Codes </font>
#
# ## <font color='blue'> Linked List Implementation </font>
#
# ## <font color='blue'> Queue Implementation Using Stack </font>
#
# ## <font color='blue'> Priority Queue Implementation Using Sorted Linked List </font>

# %%
class Node:
    def __init__(self, data):
        self.data = data
        self.next = None

# This is a Linked list implementation of Stack data structure in genric way. 
# This code conatins basic ADT of stack
    # * Enqueue
    # * Dequeue
    # * GetFront
    # * GetRear
    # * Show
    
class Queue:
    def __init__(self):
        self.front = None
        self.rear = None
        
    # This method will insert data in the queue. 
    def enqueue(self, data):
        tmp = Node(data)
        if self.rear is None:
            self.front = self.rear = tmp
            return
        else:
            self.rear.next = self.rear = tmp
    
    # Checking if Stack is empty
    def isempty(self):
        # 1. If front is None
            #a. Queue is empty 
        if self.front is None:
            return True
        #2. Queue has some element. 
        else:
            return False
    
    def getrear(self):
        # 1. Checking if Queue is empty
        if self.isempty():
            print("Queue is empty")
        else:
            # printing the rear element of the queue.
            print("Rear element of Queue is :", end =" ")
            print(self.rear.data)
            
    def getfront(self):
        # 1. Checking if Queue is empty
        if self.isempty():
            print("Queue is empty")
        else:
            # printing the front element of the queue.
            print("Front element of Queue is :", end =" ")
            print(self.front.data)
    
    # Method to delete the elements one by one form the queue    
    def deque(self):
        #1. Check if queue is empty
        if self.isempty():
            print("Queue is empty")
            self.front = None
            self.rear = None
        #2. If the queue has some element then deletion can happen
        # we need to update the front as well 
        else:
            #a. save the front reference in another variable
            #b. Move the front pointer to the next node
            #c. Print the data
            #d. delete the node data
            tmp = self.front
            print("Deleted element is element of Queue is :", end =" ")
            print(tmp.data)
            self.front = tmp.next
            del tmp
            if self.isempty():
                self.rear = None

# %%
class Stack:

    def __init__(self):
        self.items = []

    def push(self, item):
        self.items.append(item)

    def pop(self):
        return self.items.pop()

    def size(self):
        return len(self.items)

    def is_empty(self):
        return self.items == []

class Queue(object):

    def __init__(self):

        # Initializing two Stacks
        self.stack1 = Stack()
        self.stack2 = Stack()

    def enqueue(self, item):
        self.stack1.push(item)

    def dequeue(self):
        
        if self.stack1.size() == 0 and self.stack2.size() == 0:
            print("Queue is Empty")
            return
 
        # if s2 is empty and s1 has elements
        elif self.stack2.size() == 0 and self.stack1.size() > 0:
            while self.stack1.size():
                temp = self.stack1.pop()
                self.stack2.push(temp)
            return self.stack2.pop()
 
        else:
            return self.stack2.pop() 

# Driver code
if __name__ == '__main__':
    q = Queue()
    q.enqueue(1)
    q.enqueue(2)
    q.enqueue(3)
    a = q.dequeue()
    print(a)
    b = q.dequeue()
    print(b)
    q.enqueue(5)
    c = q.dequeue()
    print(c)
    q.enqueue(6)
    print(q.dequeue())
    print(q.dequeue())
    
    """
    Order of enqueue operation in queue is 1, 2, 3, 5, 6
    Deletion of elements from queue should happen in following order: 1, 2, 3, 5, 6
    """
    
    """
    # Testing code for large input
    for i in range(5):
        print(i)
        q.enqueue(i)
    for i in range(5):
        print(q.dequeue())
    """

# %%
class Node:
    def __init__(self, data, priority):
        self.data = data
        self.priority = priority
        self.next = None

class Queue:
    
    def __init__(self):
        self.front = None
        self.rear = None

    # This method will insert data in the queue. 
    def enqueue(self, val, prior):
        # Creating the node for insertion
        tmp = Node(val, prior)
        # Checking if the Queue is empty
        if self.rear is None:
            self.front = self.rear = tmp
            return
        
        # if queue has only one element 
        # Inserting the element and rearraning the front
        if (self.front.priority > prior):
            tmp.next = self.front
            self.front = tmp
            
        # Finding the right position to insert the elelemnt in the queue
        # this will ensure the priority of elelemnts are arranged.  
        else:
            p = self.front
            while p.next != None and p.next.priority <prior:
                p = p.next
            
            tmp.next = p.next
            p.next = tmp

    def isempty(self):
        # 1. If front is None
        #a. Queue is empty 
        if self.front is None:
            return True
        #2. Queue has some element. 
        else:
            return False


    def dequeue(self):
        #1. Check if queue is empty
        if self.isempty():
            print("Queue is empty")
            self.front = None
            self.rear = None
        #2. If the queue has some element then deletion can happen
        # we need to update the front as well 
        else:
            #a. save the front reference in another variable
            #b. Move the front pointer to the next node
            #c. Print the data
            #d. delete the node data
            tmp = self.front
            print("Deleted element is element of Queue is :", end =" ")
            print(tmp.data)
            self.front = tmp.next
            del tmp
            if self.isempty():
                self.rear = None

q = Queue()

q.enqueue("P1", 10)
q.enqueue("P2", 12)
q.enqueue("P3", 1)
q.enqueue("P4", 2)

q.dequeue()
q.dequeue()
q.dequeue()
q.dequeue()
q.dequeue()
